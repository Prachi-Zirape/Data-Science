# %%
#Date-10/31/22
#1-Create a dataframe of ten rows, four columns with random values. 
#Write a Pandas program to highlight the negative numbers red and positive numbers black
import pandas as pd
import numpy as np

np.random.seed(24)
df=pd.DataFrame({'A':np.linspace(1,10,10)})
df=pd.concat([df,pd.DataFrame(np.random.randn(10,4),columns=list('BCDE'))],axis=1)
print("Original array:")
print(df)

def color_neg_red(val):
    color='red' if val<0 else 'black'
    return 'color:%s' %color

print("\nNegative numbers red and positive numbers black:")
df.style.applymap(color_neg_red)
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Negative numbers red and positive numbers black:
# <style type="text/css">
# ...

# %%
#2-Write a Pandas program which will highlight the nan values
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan

print("highlight null values in red")
df.style.highlight_null(null_color='red')
# Out:
# highlight null values in red
# <style type="text/css">
# #T_1b576_row0_col2, #T_1b576_row3_col3, #T_1b576_row4_col1, #T_1b576_row9_col4 {
#   background-color: red;
# }
# </style>
# <table id="T_1b576_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b576_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b576_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1b576_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_1b576_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_1b576_row0_col3" class="data row0 col3" >-0.316280</td>
# ...

# %%
#3-Write a Pandas program to highlight the maximum value in each column
def highlight_max(s):
    '''
    highlight the maximum in a Series green.
    '''
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

print("\nHighlight the maximum value in each column:")
df.style.apply(highlight_max,subset=pd.IndexSlice[:, ['B', 'C', 'D', 'E']])
# Out:
# Highlight the maximum value in each column:
# <style type="text/css">
# #T_49c88_row2_col4, #T_49c88_row6_col2, #T_49c88_row8_col1, #T_49c88_row8_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_49c88_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49c88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49c88_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_49c88_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_49c88_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_49c88_row0_col3" class="data row0 col3" >-0.316280</td>
# ...

# %%
#4- Write a Pandas program to highlight the minimum value in each column
def highlight_min(s):
    '''
    highlight the maximum in a Series green.
    '''
    is_max = s == s.min()
    return ['background-color: red' if v else '' for v in is_max]

print("\nHighlight the maximum value in each column:")
df.style.apply(highlight_min,subset=pd.IndexSlice[:, ['B', 'C', 'D', 'E']])
# Out:
# Highlight the maximum value in each column:
# <style type="text/css">
# #T_ae448_row1_col2, #T_ae448_row2_col1, #T_ae448_row8_col4, #T_ae448_row9_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_ae448_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae448_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae448_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ae448_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_ae448_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_ae448_row0_col3" class="data row0 col3" >-0.316280</td>
# ...

# %%
#5-Write a Pandas program to highlight the maximum value in last two columns
def highlight_max(s):
    '''
    highlight the maximum in a Series green.
    '''
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

print("\nHighlight the maximum value in each column:")
df.style.apply(highlight_max,subset=pd.IndexSlice[:, ['B', 'C']])
# Out:
# Highlight the maximum value in each column:
# <style type="text/css">
# #T_c1fab_row6_col2, #T_c1fab_row8_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_c1fab_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1fab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1fab_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c1fab_row0_col1" class="data row0 col1" >1.329212</td>
#       <td id="T_c1fab_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_c1fab_row0_col3" class="data row0 col3" >-0.316280</td>
#       <td id="T_c1fab_row0_col4" class="data row0 col4" >-0.990810</td>
# ...

# %%
#6-Write a Pandas program to set dataframe background Color black and font color yellow.
print("\nBackground:black - fontcolor:yelow")
df.style.set_properties(**{'background-color': 'black',
                           'color': 'yellow'})
# Out:
# Background:black - fontcolor:yelow
# <style type="text/css">
# ...

# %%
#7-highlight dataframe's specific columns
def highlight_cols(s):
    color='grey'
    return 'background-color: %s' %color
print("\nHighlight specific columns:")
df.style.applymap(highlight_cols,subset=pd.IndexSlice[:,['B','D']])
# Out:
# Highlight specific columns:
# <style type="text/css">
# #T_28f5b_row0_col1, #T_28f5b_row0_col3, #T_28f5b_row1_col1, #T_28f5b_row1_col3, #T_28f5b_row2_col1, #T_28f5b_row2_col3, #T_28f5b_row3_col1, #T_28f5b_row3_col3, #T_28f5b_row4_col1, #T_28f5b_row4_col3, #T_28f5b_row5_col1, #T_28f5b_row5_col3, #T_28f5b_row6_col1, #T_28f5b_row6_col3, #T_28f5b_row7_col1, #T_28f5b_row7_col3, #T_28f5b_row8_col1, #T_28f5b_row8_col3, #T_28f5b_row9_col1, #T_28f5b_row9_col3 {
#   background-color: grey;
# }
# </style>
# <table id="T_28f5b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28f5b_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
#8-highlight dataframe's specific columns with different colors
print("\nDifferent background color:")
coldict={'B':'red', 'D':'yellow'}

def highlight_cols(x):
    #copy df to new - original data are not changed
    df = x.copy()
    #select all values to default value - red color
    df.loc[:,:] = 'background-color: red'
    #overwrite values grey color
    df[['B','C', 'E']] = 'background-color: grey'
    #return color df
    return df    
df.style.apply(highlight_cols, axis=None)
# Out:
# Different background color:
# <style type="text/css">
# #T_0d55e_row0_col0, #T_0d55e_row0_col3, #T_0d55e_row1_col0, #T_0d55e_row1_col3, #T_0d55e_row2_col0, #T_0d55e_row2_col3, #T_0d55e_row3_col0, #T_0d55e_row3_col3, #T_0d55e_row4_col0, #T_0d55e_row4_col3, #T_0d55e_row5_col0, #T_0d55e_row5_col3, #T_0d55e_row6_col0, #T_0d55e_row6_col3, #T_0d55e_row7_col0, #T_0d55e_row7_col3, #T_0d55e_row8_col0, #T_0d55e_row8_col3, #T_0d55e_row9_col0, #T_0d55e_row9_col3 {
#   background-color: red;
# }
# ...

# %%
#9-display the dataframe in table style
